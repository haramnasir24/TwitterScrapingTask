# %% [markdown]
# **Using ntscraper (nitter)**

# %% [markdown]
#   IP Rotation

# %%
# !pip install ntscraper
# !pip install requests
# Out:
# Collecting ntscraper
#   Downloading ntscraper-0.3.13-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from ntscraper) (2.31.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from ntscraper) (4.12.3)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from ntscraper) (4.9.4)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->ntscraper) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->ntscraper) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->ntscraper) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->ntscraper) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->ntscraper) (2024.7.4)
# Downloading ntscraper-0.3.13-py3-none-any.whl (11 kB)
# Installing collected packages: ntscraper
# Successfully installed ntscraper-0.3.13
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2024.7.4)

# %%
from ntscraper import Nitter
import pandas as pd

from tqdm import tqdm

# Load valid proxies
with open('/content/drive/MyDrive/Work/WebScrapingTask/proxy_list.txt', 'r') as f:
    proxies = f.read().split("\n")

# Initialize scraper
scraper = Nitter(log_level=1, skip_instance_check=False)

# Function to scrape tweets using a proxy
def scrape_tweets_with_proxy(proxy, query, count):
    scraper.proxies = {"http": proxy, "https": proxy}
    tweets = scraper.get_tweets(query, mode="term", number=count)
    return tweets

# user input
query = input("Enter the search query (e.g., Data Science): ")
tweet_count = int(input("Enter the number of tweets to scrape: "))

data = {
    'link': [],
    'text': [],
    'user': [],
    'likes': [],
    'quotes': [],
    'retweets': [],
    'comments': []
}

# Rotate through proxies to scrape tweets
# Progress tracking
pbar = tqdm(total=tweet_count)
counter = 0
while len(data['text']) < tweet_count:
    proxy = proxies[counter % len(proxies)]
    try:
        tweets = scrape_tweets_with_proxy(proxy, query, min(100, tweet_count - len(data['text'])))
        for tweet in tweets['tweets']:
            data['link'].append(tweet['link'])
            data['text'].append(tweet['text'])
            data['user'].append(tweet['user']['name'])
            data['likes'].append(tweet['stats']['likes'])
            data['quotes'].append(tweet['stats']['quotes'])
            data['retweets'].append(tweet['stats']['retweets'])
            data['comments'].append(tweet['stats']['comments'])
        pbar.update(len(tweets['tweets']))
    except Exception as e:
        print(f"Failed with proxy {proxy}: {e}")
    finally:
        counter += 1

pbar.close()

# Save scraped data to a DataFrame
df = pd.DataFrame(data)

df.to_csv('/content/drive/MyDrive/Work/WebScrapingTask/dynamic_scraped_tweets.csv', index=False)
print("Scraping completed and saved to CSV.")
# Out:
# Testing instances: 100%|██████████| 77/77 [01:16<00:00,  1.01it/s]
# Enter the search query (e.g., Data Science): Pakistan
# Enter the number of tweets to scrape: 1500
#   0%|          | 0/1500 [00:00<?, ?it/s]INFO:root:No instance specified, using random instance https://nitter.privacydev.net
# INFO:root:Current stats for Pakistan: 17 tweets, 0 threads...
# INFO:root:Current stats for Pakistan: 34 tweets, 0 threads...
# INFO:root:Current stats for Pakistan: 50 tweets, 0 threads...
# WARNING:root:Empty page on https://nitter.privacydev.net
#   3%|▎         | 50/1500 [00:21<10:31,  2.30it/s]INFO:root:No instance specified, using random instance https://nitter.privacydev.net
# INFO:root:Current stats for Pakistan: 17 tweets, 0 threads...
# INFO:root:Current stats for Pakistan: 34 tweets, 0 threads...
# INFO:root:Current stats for Pakistan: 50 tweets, 0 threads...
# WARNING:root:Empty page on https://nitter.privacydev.net
#   7%|▋         | 100/1500 [00:39<09:01,  2.59it/s]INFO:root:No instance specified, using random instance https://nitter.privacydev.net
# INFO:root:Current stats for Pakistan: 17 tweets, 0 threads...
# INFO:root:Current stats for Pakistan: 34 tweets, 0 threads...
# INFO:root:Current stats for Pakistan: 50 tweets, 0 threads...
# WARNING:root:Empty page on https://nitter.privacydev.net
#  10%|█         | 150/1500 [01:00<09:04,  2.48it/s]INFO:root:No instance specified, using random instance https://nitter.privacydev.net
# INFO:root:Current stats for Pakistan: 17 tweets, 0 threads...
# INFO:root:Current stats for Pakistan: 34 tweets, 0 threads...
# INFO:root:Current stats for Pakistan: 50 tweets, 0 threads...
# WARNING:root:Empty page on https://nitter.privacydev.net
#  13%|█▎        | 200/1500 [01:20<08:37,  2.51it/s]INFO:root:No instance specified, using random instance https://nitter.privacydev.net
# INFO:root:Current stats for Pakistan: 17 tweets, 0 threads...
# INFO:root:Current stats for Pakistan: 34 tweets, 0 threads...
# INFO:root:Current stats for Pakistan: 50 tweets, 0 threads...
# WARNING:root:Empty page on https://nitter.privacydev.net
#  17%|█▋        | 250/1500 [01:36<07:49,  2.66it/s]INFO:root:No instance specified, using random instance https://nitter.privacydev.net
# INFO:root:Current stats for Pakistan: 17 tweets, 0 threads...
# INFO:root:Current stats for Pakistan: 34 tweets, 0 threads...
# INFO:root:Current stats for Pakistan: 50 tweets, 0 threads...
# WARNING:root:Empty page on https://nitter.privacydev.net
#  20%|██        | 300/1500 [01:54<07:24,  2.70it/s]INFO:root:No instance specified, using random instance https://nitter.privacydev.net
# INFO:root:Current stats for Pakistan: 17 tweets, 0 threads...
# INFO:root:Current stats for Pakistan: 34 tweets, 0 threads...
# INFO:root:Current stats for Pakistan: 50 tweets, 0 threads...
# WARNING:root:Empty page on https://nitter.privacydev.net
#  23%|██▎       | 350/1500 [02:15<07:20,  2.61it/s]INFO:root:No instance specified, using random instance https://nitter.privacydev.net
# INFO:root:Current stats for Pakistan: 17 tweets, 0 threads...
# INFO:root:Current stats for Pakistan: 34 tweets, 0 threads...
# INFO:root:Current stats for Pakistan: 50 tweets, 0 threads...
# WARNING:root:Empty page on https://nitter.privacydev.net
#  27%|██▋       | 400/1500 [02:34<07:01,  2.61it/s]INFO:root:No instance specified, using random instance https://nitter.privacydev.net
# INFO:root:Current stats for Pakistan: 17 tweets, 0 threads...
# INFO:root:Current stats for Pakistan: 34 tweets, 0 threads...
# INFO:root:Current stats for Pakistan: 50 tweets, 0 threads...
# WARNING:root:Empty page on https://nitter.privacydev.net
#  30%|███       | 450/1500 [02:54<06:50,  2.56it/s]INFO:root:No instance specified, using random instance https://nitter.privacydev.net
# INFO:root:Current stats for Pakistan: 17 tweets, 0 threads...
# INFO:root:Current stats for Pakistan: 34 tweets, 0 threads...
# INFO:root:Current stats for Pakistan: 50 tweets, 0 threads...
# WARNING:root:Empty page on https://nitter.privacydev.net
#  33%|███▎      | 500/1500 [03:14<06:31,  2.55it/s]INFO:root:No instance specified, using random instance https://nitter.privacydev.net
# INFO:root:Current stats for Pakistan: 17 tweets, 0 threads...
# INFO:root:Current stats for Pakistan: 34 tweets, 0 threads...
# INFO:root:Current stats for Pakistan: 50 tweets, 0 threads...
# WARNING:root:Empty page on https://nitter.privacydev.net
#  37%|███▋      | 550/1500 [03:31<05:54,  2.68it/s]INFO:root:No instance specified, using random instance https://nitter.privacydev.net
# INFO:root:Current stats for Pakistan: 17 tweets, 0 threads...
# INFO:root:Current stats for Pakistan: 34 tweets, 0 threads...
# INFO:root:Current stats for Pakistan: 50 tweets, 0 threads...
# WARNING:root:Empty page on https://nitter.privacydev.net
#  40%|████      | 600/1500 [03:48<05:31,  2.72it/s]INFO:root:No instance specified, using random instance https://nitter.privacydev.net
# INFO:root:Current stats for Pakistan: 17 tweets, 0 threads...
# INFO:root:Current stats for Pakistan: 34 tweets, 0 threads...
# INFO:root:Current stats for Pakistan: 50 tweets, 0 threads...
# WARNING:root:Empty page on https://nitter.privacydev.net
#  43%|████▎     | 650/1500 [04:05<05:05,  2.78it/s]INFO:root:No instance specified, using random instance https://nitter.privacydev.net
# INFO:root:Current stats for Pakistan: 17 tweets, 0 threads...
# INFO:root:Current stats for Pakistan: 34 tweets, 0 threads...
# INFO:root:Current stats for Pakistan: 50 tweets, 0 threads...
# WARNING:root:Empty page on https://nitter.privacydev.net
#  47%|████▋     | 700/1500 [04:22<04:42,  2.83it/s]INFO:root:No instance specified, using random instance https://nitter.privacydev.net
# INFO:root:Current stats for Pakistan: 17 tweets, 0 threads...
# INFO:root:Current stats for Pakistan: 34 tweets, 0 threads...
# INFO:root:Current stats for Pakistan: 50 tweets, 0 threads...
# WARNING:root:Empty page on https://nitter.privacydev.net
#  50%|█████     | 750/1500 [04:39<04:18,  2.90it/s]INFO:root:No instance specified, using random instance https://nitter.privacydev.net
# INFO:root:Current stats for Pakistan: 17 tweets, 0 threads...
# INFO:root:Current stats for Pakistan: 34 tweets, 0 threads...
# INFO:root:Current stats for Pakistan: 50 tweets, 0 threads...
# WARNING:root:Empty page on https://nitter.privacydev.net
#  53%|█████▎    | 800/1500 [04:54<03:54,  2.98it/s]INFO:root:No instance specified, using random instance https://nitter.privacydev.net
# INFO:root:Current stats for Pakistan: 17 tweets, 0 threads...
# INFO:root:Current stats for Pakistan: 34 tweets, 0 threads...
# INFO:root:Current stats for Pakistan: 50 tweets, 0 threads...
# WARNING:root:Empty page on https://nitter.privacydev.net
#  57%|█████▋    | 850/1500 [05:11<03:39,  2.97it/s]INFO:root:No instance specified, using random instance https://nitter.privacydev.net
# INFO:root:Current stats for Pakistan: 17 tweets, 0 threads...
# INFO:root:Current stats for Pakistan: 34 tweets, 0 threads...
# INFO:root:Current stats for Pakistan: 50 tweets, 0 threads...
# WARNING:root:Empty page on https://nitter.privacydev.net
#  60%|██████    | 900/1500 [05:28<03:22,  2.96it/s]INFO:root:No instance specified, using random instance https://nitter.privacydev.net
# INFO:root:Current stats for Pakistan: 17 tweets, 0 threads...
# INFO:root:Current stats for Pakistan: 34 tweets, 0 threads...
# INFO:root:Current stats for Pakistan: 50 tweets, 0 threads...
# WARNING:root:Empty page on https://nitter.privacydev.net
#  63%|██████▎   | 950/1500 [05:45<03:03,  2.99it/s]INFO:root:No instance specified, using random instance https://nitter.privacydev.net
# INFO:root:Current stats for Pakistan: 17 tweets, 0 threads...
# INFO:root:Current stats for Pakistan: 34 tweets, 0 threads...
# INFO:root:Current stats for Pakistan: 50 tweets, 0 threads...
# WARNING:root:Empty page on https://nitter.privacydev.net
#  67%|██████▋   | 1000/1500 [06:02<02:47,  2.98it/s]INFO:root:No instance specified, using random instance https://nitter.privacydev.net
# INFO:root:Current stats for Pakistan: 17 tweets, 0 threads...
# INFO:root:Current stats for Pakistan: 34 tweets, 0 threads...
# INFO:root:Current stats for Pakistan: 50 tweets, 0 threads...
# WARNING:root:Empty page on https://nitter.privacydev.net
#  70%|███████   | 1050/1500 [06:18<02:30,  2.98it/s]INFO:root:No instance specified, using random instance https://nitter.privacydev.net
# INFO:root:Current stats for Pakistan: 17 tweets, 0 threads...
# INFO:root:Current stats for Pakistan: 34 tweets, 0 threads...
# INFO:root:Current stats for Pakistan: 50 tweets, 0 threads...
# WARNING:root:Empty page on https://nitter.privacydev.net
#  73%|███████▎  | 1100/1500 [06:35<02:14,  2.98it/s]INFO:root:No instance specified, using random instance https://nitter.privacydev.net
# INFO:root:Current stats for Pakistan: 17 tweets, 0 threads...
# INFO:root:Current stats for Pakistan: 34 tweets, 0 threads...
# INFO:root:Current stats for Pakistan: 50 tweets, 0 threads...
# WARNING:root:Empty page on https://nitter.privacydev.net
#  77%|███████▋  | 1150/1500 [06:53<01:59,  2.93it/s]INFO:root:No instance specified, using random instance https://nitter.privacydev.net
# INFO:root:Current stats for Pakistan: 17 tweets, 0 threads...
# INFO:root:Current stats for Pakistan: 34 tweets, 0 threads...
# INFO:root:Current stats for Pakistan: 50 tweets, 0 threads...
# WARNING:root:Empty page on https://nitter.privacydev.net
#  80%|████████  | 1200/1500 [07:10<01:42,  2.93it/s]INFO:root:No instance specified, using random instance https://nitter.privacydev.net
# INFO:root:Current stats for Pakistan: 17 tweets, 0 threads...
# INFO:root:Current stats for Pakistan: 34 tweets, 0 threads...
# INFO:root:Current stats for Pakistan: 50 tweets, 0 threads...
# WARNING:root:Empty page on https://nitter.privacydev.net
#  83%|████████▎ | 1250/1500 [07:26<01:24,  2.97it/s]INFO:root:No instance specified, using random instance https://nitter.privacydev.net
# INFO:root:Current stats for Pakistan: 17 tweets, 0 threads...
# INFO:root:Current stats for Pakistan: 34 tweets, 0 threads...
# INFO:root:Current stats for Pakistan: 50 tweets, 0 threads...
# WARNING:root:Empty page on https://nitter.privacydev.net
#  87%|████████▋ | 1300/1500 [07:44<01:07,  2.94it/s]INFO:root:No instance specified, using random instance https://nitter.privacydev.net
# INFO:root:Current stats for Pakistan: 17 tweets, 0 threads...
# INFO:root:Current stats for Pakistan: 34 tweets, 0 threads...
# INFO:root:Current stats for Pakistan: 50 tweets, 0 threads...
# WARNING:root:Empty page on https://nitter.privacydev.net
#  90%|█████████ | 1350/1500 [08:01<00:51,  2.91it/s]INFO:root:No instance specified, using random instance https://nitter.privacydev.net
# INFO:root:Current stats for Pakistan: 17 tweets, 0 threads...
# INFO:root:Current stats for Pakistan: 34 tweets, 0 threads...
# INFO:root:Current stats for Pakistan: 50 tweets, 0 threads...
# WARNING:root:Empty page on https://nitter.privacydev.net
#  93%|█████████▎| 1400/1500 [08:18<00:33,  2.95it/s]INFO:root:No instance specified, using random instance https://nitter.privacydev.net
# INFO:root:Current stats for Pakistan: 17 tweets, 0 threads...
# INFO:root:Current stats for Pakistan: 34 tweets, 0 threads...
# INFO:root:Current stats for Pakistan: 50 tweets, 0 threads...
# WARNING:root:Empty page on https://nitter.privacydev.net
#  97%|█████████▋| 1450/1500 [08:34<00:16,  2.99it/s]INFO:root:No instance specified, using random instance https://nitter.privacydev.net
# INFO:root:Current stats for Pakistan: 17 tweets, 0 threads...
# INFO:root:Current stats for Pakistan: 34 tweets, 0 threads...
# INFO:root:Current stats for Pakistan: 50 tweets, 0 threads...
# 100%|██████████| 1500/1500 [08:47<00:00,  2.85it/s]
# Scraping completed and saved to CSV.

# %% [markdown]
# Pre-processing and storing in FireBase DB

# %%
# pre-processing and cleaning the scraped data

df = pd.read_csv('/content/drive/MyDrive/Work/WebScrapingTask/dynamic_scraped_tweets.csv')

df.head()
# Out:
#                                                 link  \
# 0  https://twitter.com/ImranKhanPTI/status/403945...
# 1  https://twitter.com/pakistan_untold/status/181...
# 2  https://twitter.com/LoverCrick79813/status/181...
# 3  https://twitter.com/MrSinha_/status/1816679057...
# 4  https://twitter.com/SRKNation2023/status/18171...
#
#                                                 text             user  likes  \
# 0  Dharti Hamari, Marzi Hamari. Our Land, Our Way...       Imran Khan  21162
# 1  "...Hatred against Hindus in Pakistan is runni...  Pakistan Untold    481
# 2  But Pakistan Ke Pass Sirf Zimbabar Hai 😂. 5 Wi...    Cricket Lover      0
# 3  Whenever I remember #KargilWar, it reminds me ...         Mr Sinha  37823
# 4  ICC Champions Trophy 2025 in Pakistan will out...       SRK Nation      0
#
#    quotes  retweets  comments
# 0     245      9782       383
# 1       1       234         4
# 2       0         0         0
# 3     319     11919      1367
# 4       0         0         0

# %%
df.drop_duplicates(subset='link', inplace=True)

# %%
df.shape
# Out:
# (50, 7)

# %%
import re

# 1. Remove duplicates based on 'link'
df.drop_duplicates(subset='link', inplace=True)

# 2. Handling missing values (if any column should not have nulls)
df.fillna({'text': '', 'user': 'Unknown'}, inplace=True)

# 3. Normalize text data
df['text'] = df['text'].str.lower()
df['user'] = df['user'].str.lower()

# 4. Text cleaning (removing URLs and special characters from text)
def clean_text(text):
    text = re.sub(r'http\S+', '', text)  # Remove URLs
    text = re.sub(r'@\w+', '', text)  # Remove mentions
    text = re.sub(r'#\w+', '', text)  # Remove hashtags
    text = re.sub(r'[^A-Za-z0-9\s]+', '', text)  # Remove special characters
    return text.strip()

df['text'] = df['text'].apply(clean_text)

# 5. Convert numerical fields to appropriate types (if necessary)
df['likes'] = df['likes'].astype(int)
df['quotes'] = df['quotes'].astype(int)
df['retweets'] = df['retweets'].astype(int)
df['comments'] = df['comments'].astype(int)

# Output the cleaned data
df.to_csv('/content/drive/MyDrive/Work/WebScrapingTask/cleaned_tweets.csv', index=False)
print("Data has been preprocessed and saved to cleaned_tweets.csv")
# Out:
# Data has been preprocessed and saved to cleaned_tweets.csv

# %%
import pandas as pd

data = pd.read_csv("/content/cleaned_tweets.csv")

data.head()
# Out:
#                                                 link  \
# 0  https://twitter.com/agentjay2009/status/181668...
# 1  https://twitter.com/saniaazizr/status/18167299...
# 2  https://twitter.com/PPP_Org/status/18167284556...
# 3  https://twitter.com/AskAnshul/status/181671359...
# 4  https://twitter.com/trunicle/status/1816317833...
#
#                                                 text  \
# 0  another protest day today may we see the relea...
# 1  except that both india and pakistan have been ...
# 2  the 69th birthday of president asif ali zardar...
# 3  pakistani army refused to take the dead bodies...
# 4  india please grant us visas we wish to marry i...
#
#                            user  likes  quotes  retweets  comments
# 0                  jibran ilyas   1772       8       953        33
# 1                 sania aziz 🇵🇸      0       0         0         0
# 2  pakistan peoples party - ppp      2       0         4         0
# 3                 anshul saxena    683       2       216        16
# 4             trunicle ट्रूनिकल   2089      40       490       198

# %%
data.shape
# Out:
# (32, 7)

# %%
# storing in firebase database

# !pip install firebase-admin pandas
# Out:
# Requirement already satisfied: firebase-admin in /usr/local/lib/python3.10/dist-packages (6.5.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.0.3)
# Requirement already satisfied: cachecontrol>=0.12.6 in /usr/local/lib/python3.10/dist-packages (from firebase-admin) (0.14.0)
# Requirement already satisfied: google-api-python-client>=1.7.8 in /usr/local/lib/python3.10/dist-packages (from firebase-admin) (2.137.0)
# Requirement already satisfied: google-cloud-storage>=1.37.1 in /usr/local/lib/python3.10/dist-packages (from firebase-admin) (2.8.0)
# Requirement already satisfied: pyjwt>=2.5.0 in /usr/local/lib/python3.10/dist-packages (from pyjwt[crypto]>=2.5.0->firebase-admin) (2.8.0)
# Requirement already satisfied: google-api-core<3.0.0dev,>=1.22.1 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (2.19.1)
# Requirement already satisfied: google-cloud-firestore>=2.9.1 in /usr/local/lib/python3.10/dist-packages (from firebase-admin) (2.16.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.25.2)
# Requirement already satisfied: requests>=2.16.0 in /usr/local/lib/python3.10/dist-packages (from cachecontrol>=0.12.6->firebase-admin) (2.31.0)
# Requirement already satisfied: msgpack<2.0.0,>=0.5.2 in /usr/local/lib/python3.10/dist-packages (from cachecontrol>=0.12.6->firebase-admin) (1.0.8)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (1.63.2)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0.dev0,>=3.19.5 in /usr/local/lib/python3.10/dist-packages (from google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (3.20.3)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /usr/local/lib/python3.10/dist-packages (from google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (1.24.0)
# Requirement already satisfied: google-auth<3.0.dev0,>=2.14.1 in /usr/local/lib/python3.10/dist-packages (from google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (2.27.0)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (1.64.1)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (1.48.2)
# Requirement already satisfied: httplib2<1.dev0,>=0.19.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client>=1.7.8->firebase-admin) (0.22.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client>=1.7.8->firebase-admin) (0.2.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client>=1.7.8->firebase-admin) (4.1.1)
# Requirement already satisfied: google-cloud-core<3.0.0dev,>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from google-cloud-firestore>=2.9.1->firebase-admin) (2.4.1)
# Requirement already satisfied: google-resumable-media>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from google-cloud-storage>=1.37.1->firebase-admin) (2.7.1)
# Requirement already satisfied: cryptography>=3.4.0 in /usr/local/lib/python3.10/dist-packages (from pyjwt[crypto]>=2.5.0->firebase-admin) (42.0.8)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=3.4.0->pyjwt[crypto]>=2.5.0->firebase-admin) (1.16.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (5.4.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (4.9)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /usr/local/lib/python3.10/dist-packages (from google-resumable-media>=2.3.2->google-cloud-storage>=1.37.1->firebase-admin) (1.5.0)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.10/dist-packages (from httplib2<1.dev0,>=0.19.0->google-api-python-client>=1.7.8->firebase-admin) (3.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.16.0->cachecontrol>=0.12.6->firebase-admin) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.16.0->cachecontrol>=0.12.6->firebase-admin) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.16.0->cachecontrol>=0.12.6->firebase-admin) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.16.0->cachecontrol>=0.12.6->firebase-admin) (2024.7.4)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=3.4.0->pyjwt[crypto]>=2.5.0->firebase-admin) (2.22)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (0.6.0)

# %%
# Step 1: Import necessary libraries
import firebase_admin
from firebase_admin import credentials, firestore
import pandas as pd

# Step 2: Initialize the Firebase Admin SDK
# Check if an app is already initialized
if not firebase_admin._apps:
    cred = credentials.Certificate('/content/twitterscrapeddata-3f305-firebase-adminsdk-q7tef-644196b17c.json')
    firebase_admin.initialize_app(cred)

# Step 3: Initialize Firestore
db = firestore.client()

# Step 4: Load your DataFrame
data = pd.read_csv("/content/cleaned_tweets.csv")

# Step 5: Convert DataFrame to dictionary format
df_dict = data.to_dict(orient='records')  # Each row will be a separate dictionary

# Step 6: Upload each row to Firestore
collection_name = 'twitter_data'  # Replace with your Firestore collection name

for index, record in enumerate(df_dict):
    doc_ref = db.collection(collection_name).document(f'record_{index}')
    doc_ref.set(record)

print("Data uploaded successfully.")
# Out:
# Data uploaded successfully.
